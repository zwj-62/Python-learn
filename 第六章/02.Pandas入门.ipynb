# %%
import pandas as pd
#构造DataFrame ----创建数据集（学员成绩信息）
df = pd.DataFrame([
    {"姓名": "小王1", "语文": 90, "数学": 80, "英语": 70},
    {"姓名": "小李1", "语文": 80, "数学": 90, "英语": 80},
    {"姓名": "小张", "语文": 70, "数学": 80, "英语": 90},
    {"姓名": "小赵", "语文": 60, "数学": 70, "英语": 80},
    {"姓名": "小孙", "语文": 80, "数学": 90, "英语": 70},
    {"姓名": "小李2", "语文": 80, "数学": 80, "英语": 90},
    {"姓名": "小王2", "语文": 90, "数学": 80, "英语": 80},
    {"姓名": "小王3", "语文": 90, "数学": 80, "英语": 90},
    {"姓名": "小王4", "语文": 90, "数学": 80, "英语": 80}
])
#统计计算
f" 语文最高分:{df['语文'].max()},最低分：{df['语文'].min()},平均分：{df['语文'].mean()}"
# Out:
# ' 语文最高分:90,最低分：60,平均分：81.11111111111111'
