# %%
print("成功跑通Jupyter啦！")
# Out:
# 成功跑通Jupyter啦！

# %%
a=100
b=200
print(a+b)
# Out:
# 300

# %%
a=100
b=200
c=300
a+b+c
# Out:
# 600

# %%
x=1000
y=2000
x+y
# Out:
# 3000

# %%
a+b+c+x+y
# Out:
# 3600

# %%
x*y
# Out:
# 2000000
